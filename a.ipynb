# %%
import matplotlib.pyplot as plt

a=["apple","banana","cherry"]
b=[24,32,17]

c=["red","blue","black"]
d=[0.3,0.6,0]

plt.pie(b,labels=a,colors=c,explode=d)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("title")
plt.legend(loc="center")

# %%
plt.plot(a,b,color="r",lw=0.3,marker="h",ms=19,mfc="g",mec="b")

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 plt.scatter(a,b,ms=8)
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
a=2

#list

a=[1,3,4,3.5,"arun",True]

a[0] + a[3] + a[1]
# Out:
# 7.5

# %%
a.append('hai')
a
# Out:
# [1, 3, 4, 3.5, 'arun', True, 'hai']

# %%
a.insert(2,"world")
a
# Out:
# [1, 3, 'world', 4, 3.5, 'arun', True, 'hai']

# %%
#a.remove("world")
a

b=a.copy()
b
# Out:
# [1, 3, 4, 3.5, 'arun', True, 'hai']

# %%
c=(1, 3, 4, 3.5, 'arun', True, 'hai')

d=list(c)
d.append(90)

d=tuple(d)
d
# Out:
# (1, 3, 4, 3.5, 'arun', True, 'hai', 90)

# %%
d={
    "a":67,
    "b":89,
    "c":90
}

d.values()
# Out:
# dict_values([67, 89, 90])

# %%
a=8

if a==8 and a>7:
    if a>3:
        if a==5:
            print("ok")
        else:
            print("hi")
    elif a==3:
        print("ok")
else:
    print("6")
# Out:
# hi

# %%
a=5
b=16
c=7
